# %% [markdown]
# # Univariate Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./../../data/prelim.csv')

# %%
df.shape
# Out:
# (13613, 29)

# %%
df.columns
# Out:
# Index(['id', 'goal', 'pledged', 'state', 'disable_communication', 'country',
#        'currency', 'currency_trailing_code', 'deadline', 'state_changed_at',
#        'created_at', 'launched_at', 'staff_pick', 'backers_count',
#        'static_usd_rate', 'usd_pledged', 'category', 'spotlight', 'name_len',
#        'name_len_clean', 'blurb_len', 'blurb_len_clean', 'deadline_weekday',
#        'created_at_weekday', 'launched_at_weekday', 'create_to_launch',
#        'launch_to_deadline', 'launch_to_state_change', 'goal_fx'],
#       dtype='object')

# %% [markdown]
# ## Numerical Variables

# %%
sns.histplot(df['goal'], bins=50, log_scale=True)
# Out:
# <AxesSubplot: xlabel='goal', ylabel='Count'>

# %%
sns.histplot(df['goal'], bins=50, log_scale=True)
# Out:
# <AxesSubplot: xlabel='goal', ylabel='Count'>

# %% [markdown]
# ## Categorical Variables

# %%
def get_value_counts(df, column):
    tmp_cnt = pd.DataFrame(df[column].value_counts()).reset_index()
    tmp_cnt.columns = [column, 'counts']
    tmp_cnt['percentage'] = tmp_cnt['counts'].apply(lambda x: round(x*100/sum(tmp_cnt['counts']), 2))
    return tmp_cnt.copy()

# %%
sns.barplot(get_value_counts(df, 'state'), x='state', y='percentage')
# Out:
# <AxesSubplot: xlabel='state', ylabel='percentage'>

# %%
plt.figure(figsize=(12,5))
ax = sns.barplot(get_value_counts(df, 'country'), x='country', y='percentage')
for container in ax.containers:
    ax.bar_label(container)

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=45)
ax = sns.barplot(get_value_counts(df, 'category'), x='category', y='percentage')
for container in ax.containers:
    ax.bar_label(container)
