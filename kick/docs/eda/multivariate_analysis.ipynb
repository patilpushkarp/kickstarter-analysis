# %% [markdown]
# # Multivariate Analysis

# %%
import pandas as pd
import plotly.io as pio
svg_renderer = pio.renderers["svg"]
svg_renderer.width = 1000
svg_renderer.height = 500
pio.renderers.default = "svg"
import plotly.express as px

# %%
df = pd.read_csv('./../../data/data.csv')

# %%
df.shape
# Out:
# (20632, 27)

# %%
df.columns
# Out:
# Index(['index', 'id', 'name', 'blurb', 'goal', 'pledged', 'state', 'slug',
#        'disable_communication', 'country', 'currency',
#        'currency_trailing_code', 'deadline', 'state_changed_at', 'created_at',
#        'launched_at', 'staff_pick', 'backers_count', 'static_usd_rate',
#        'usd_pledged', 'category', 'spotlight', 'source_url', 'name_len',
#        'name_len_clean', 'blurb_len', 'blurb_len_clean'],
#       dtype='object')

# %%
df = df[df['state'].isin(['failed', 'successful'])]

# %% [markdown]
# ## Numerical Variables

# %%
fig = px.histogram(df[df['goal']<1000001], x='goal', color='state', log_y=True, marginal='box', opacity=0.6)
fig.show()

# %%
fig = px.histogram(df, x='name_len', color='state', log_y=True, marginal='box', opacity=0.6)
fig.show()

# %%
fig = px.histogram(df, x='blurb_len', color='state', log_y=True, marginal='box', opacity=0.6)
fig.show()

# %% [markdown]
# ## Categorical Variables

# %%
fig = px.histogram(df, x='country', color='state', text_auto=True, barmode='group', histnorm='percent', log_y=True)
fig.show()

# %%
fig = px.histogram(df, x='currency', color='state', text_auto=True, barmode='group', histnorm='percent', log_y=True)
fig.show()

# %%
fig = px.histogram(df, x='category', color='state', text_auto=True, barmode='group', histnorm='percent', log_y=True)
fig.show()
